# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !ln -s "/content/drive/MyDrive/ai" "/projdir"

# %%
# ! mkdir ~/.kaggle

# %%
# ! cp "/content/drive/MyDrive/kaggle.json" ~/.kaggle/

# %%
# ! chmod 600 ~/.kaggle/kaggle.json

# %%
# ! kaggle datasets download -d andrewmvd/hard-hat-detection
# Out:
# ...
# 100% 1.22G/1.22G [00:10<00:00, 165MB/s]
# 100% 1.22G/1.22G [00:10<00:00, 129MB/s]

# %%
# ! ls
# Out:
# drive  hard-hat-detection.zip  sample_data

# %%
import os

# %%
# os.mkdir("/projdir/dataset")

# %%
# ! cp hard-hat-detection.zip "/projdir/dataset/hard_hat_detection.zip"

# %%
# !unzip -q "/projdir/dataset/hard_hat_detection.zip" -d "data"

# %%
import pathlib

# %%
path = pathlib.Path("data")

# %%
len(os.listdir("data/images"))
# Out:
# 5000

# %%
from PIL import Image

# %%
demo_image = os.listdir("data/images")[0]

# %%
img = Image.open("data/images/"+demo_image)

# %%
from matplotlib import pyplot as plt

# %%
plt.figure(figsize=(10,10))
plt.axis("off")
plt.imshow(img)
